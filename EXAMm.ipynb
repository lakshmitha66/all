# %%
import pandas as pd
df1 = pd.read_csv('D:/aiml/excel/auto_mpg.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.scatter(df['horsepower'],df['mpg'])
ax.set_title("Scatter plot of horsepower and mileage",fontsize=16)
ax.set_ylabel('Mileage per gallon',fontsize=12)
ax.set_xlabel('Horsepower',fontsize=12)
fig.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22652\3530492571.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.hist(df['horsepower'], bins=20)
ax.set_title('Distribution of Horsepower',fontsize = 17)
ax.set_ylabel('Frequency',fontsize=12)
ax.set_xlabel('Horsepower',fontsize=12)
fig.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22652\2279070076.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
line_df=df.groupby(by=['model_year'])
line_df = line_df.mean() 
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(line_df['mpg']/10,label='Mileage /10')
ax.plot(line_df['weight']/1000,label='Weight /1000')
ax.plot(line_df['horsepower']/100,label='Horsepower /100')
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22652\1070785458.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title('Distribution of mileage')
ax.boxplot(df['mpg'])
fig.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22652\357495494.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# MAP
L=[1,2,3,4,5,6,7]
list(map(lambda x: x*2,L))
# Out:
# [2, 4, 6, 8, 10, 12, 14]

# %%
list(map(lambda x: x%2==0,L))
# Out:
# [False, True, False, True, False, True, False]

# %%
students = [
{
    "name": "Jacob Martin",
    "father name" : "Ros Martin",
    "Address": "123 Hill Street",
},{
    "name": "Angela Stevens",
    "father name": "Robert Stevens",
    "Address": "3 Upper Street London",
},{
    "name": "Ricky Smart",
    "father name" : "William Smart",
    "Address": "Unknown",
}
]

# %%
list(map(lambda student: student['name'],students))
# Out:
# ['Jacob Martin', 'Angela Stevens', 'Ricky Smart']

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
#FILTER

list(filter(lambda x: x>4, L))
# Out:
# [5, 6, 7]

# %%
fruits=['apple','orange','mango','papaya']

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'papaya']

# %%
list(filter(lambda fruit: 'e' in fruit , fruits))
# Out:
# ['apple', 'orange']

# %%
#reduce

import functools

# %%
functools.reduce(lambda x,y: x+y,L)
# Out:
# 28

# %%
L1=[12,34,34,24,21,44]

# %%
functools.reduce(lambda x,y: x if x>y else y,L1)
# Out:
# 44

# %%
functools.reduce(lambda x,y: x if x<y else y,L1)
# Out:
# 12

# %%
a=df.groupby(by=['horsepower'])
a.first()
# Out:
#              mpg  cylinders  displacement  weight  acceleration  model_year  \
# horsepower
# 46.0        26.0          4          97.0    1835          20.5          70
# 48.0        43.1          4          90.0    1985          21.5          78
# 49.0        29.0          4          68.0    1867          19.5          73
# 52.0        31.0          4          76.0    1649          16.5          74
# 53.0        33.0          4          91.0    1795          17.5          75
# ...          ...        ...           ...     ...           ...         ...
# 210.0       11.0          8         318.0    4382          13.5          70
# 215.0       14.0          8         440.0    4312           8.5          70
# 220.0       14.0          8         454.0    4354           9.0          70
# 225.0       14.0          8         455.0    4425          10.0          70
# 230.0       16.0          8         400.0    4278           9.5          73
#
# ...

# %%
b=df.Sort().groupbyby=['mpg']
b.first()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22652\2212240359.py in <module>
# ----> 1 b=df.Sort().groupbyby=['mpg']
#       2 b.first()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Sort'

# %%
b=df.groupby(['mpg']).sum()
b

# %%
df1.groupby(['cylinders', 'horsepower']).agg('min')
# Out:
#                        mpg  displacement  weight  acceleration  model_year  \
# cylinders horsepower
# 3         90.0        18.0          70.0    2124          13.5          73
#           97.0        19.0          70.0    2330          13.5          72
#           100.0       23.7          70.0    2420          12.5          80
#           110.0       21.5          80.0    2720          13.5          77
# 4         46.0        26.0          97.0    1835          20.5          70
# ...                    ...           ...     ...           ...         ...
# 8         210.0       11.0         318.0    4382          13.5          70
#           215.0       10.0         360.0    4312           8.5          70
#           220.0       14.0         454.0    4354           9.0          70
#           225.0       12.0         455.0    3086          10.0          70
#           230.0       16.0         400.0    4278           9.5          73
#
# ...

# %%
df[['mpg']].agg(['min', 'max'])
# Out:
#       mpg
# min   9.0
# max  46.6

# %%
df.groupby(['model_year']).agg(min)
# Out:
#              mpg  cylinders  displacement  horsepower  weight  acceleration  \
# model_year
# 70           9.0          4          97.0        46.0    1835           8.0
# 71          12.0          4          71.0        60.0    1613          11.5
# 72          11.0          3          70.0        54.0    2100          11.0
# 73          11.0          3          68.0        46.0    1867           9.5
# 74          13.0          4          71.0        52.0    1649          13.5
# 75          13.0          4          90.0        53.0    1795          11.5
# 76          13.0          4          85.0        52.0    1795          12.0
# 77          15.0          3          79.0        58.0    1825          11.1
# 78          16.2          4          78.0        48.0    1800          11.2
# 79          15.5          4          85.0        65.0    1915          11.3
# 80          19.1          3          70.0        48.0    1835          11.4
# ...

# %%
df1=df.groupby(['horsepower']).sum()

# %%
df1
# Out:
#               mpg  cylinders  displacement  weight  acceleration  model_year
# horsepower
# 46.0         52.0          8         194.0    3785          41.5         143
# 48.0        130.8         12         270.0    6405          66.9         238
# 49.0         29.0          4          68.0    1867          19.5          73
# 52.0        136.8         16         336.0    7799          82.7         310
# 53.0         66.0          8         182.0    3590          34.9         151
# ...           ...        ...           ...     ...           ...         ...
# 210.0        11.0          8         318.0    4382          13.5          70
# 215.0        37.0         24        1240.0   13662          33.5         213
# 220.0        14.0          8         454.0    4354           9.0          70
# 225.0        40.0         24        1365.0   12462          31.0         213
# 230.0        16.0          8         400.0    4278           9.5          73
#
# [93 rows x 6 columns]

# %%
df.groupby(['horsepower']).agg(min)
# Out:
#              mpg  cylinders  displacement  weight  acceleration  model_year  \
# horsepower
# 46.0        26.0          4          97.0    1835          20.5          70
# 48.0        43.1          4          90.0    1985          21.5          78
# 49.0        29.0          4          68.0    1867          19.5          73
# 52.0        29.0          4          76.0    1649          16.5          74
# 53.0        33.0          4          91.0    1795          17.4          75
# ...          ...        ...           ...     ...           ...         ...
# 210.0       11.0          8         318.0    4382          13.5          70
# 215.0       10.0          8         360.0    4312           8.5          70
# 220.0       14.0          8         454.0    4354           9.0          70
# 225.0       12.0          8         455.0    3086          10.0          70
# 230.0       16.0          8         400.0    4278           9.5          73
#
# ...

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.groupby(['model_year']).agg(min)
# Out:
#              mpg  cylinders  displacement  horsepower  weight  acceleration  \
# model_year
# 70           9.0          4          97.0        46.0    1835           8.0
# 71          12.0          4          71.0        60.0    1613          11.5
# 72          11.0          3          70.0        54.0    2100          11.0
# 73          11.0          3          68.0        46.0    1867           9.5
# 74          13.0          4          71.0        52.0    1649          13.5
# 75          13.0          4          90.0        53.0    1795          11.5
# 76          13.0          4          85.0        52.0    1795          12.0
# 77          15.0          3          79.0        58.0    1825          11.1
# 78          16.2          4          78.0        48.0    1800          11.2
# 79          15.5          4          85.0        65.0    1915          11.3
# 80          19.1          3          70.0        48.0    1835          11.4
# ...

# %%
# Out:
#              mpg  cylinders  displacement  weight  acceleration  model_year  \
# horsepower
# 46.0        26.0          4          97.0    1950          21.0          73
# 48.0        44.3          4          90.0    2335          23.7          80
# 49.0        29.0          4          68.0    1867          19.5          73
# 52.0        44.0          4          97.0    2130          24.6          82
# 53.0        33.0          4          91.0    1795          17.5          76
# ...          ...        ...           ...     ...           ...         ...
# 210.0       11.0          8         318.0    4382          13.5          70
# 215.0       14.0          8         440.0    4735          14.0          73
# 220.0       14.0          8         454.0    4354           9.0          70
# 225.0       14.0          8         455.0    4951          11.0          73
# 230.0       16.0          8         400.0    4278           9.5          73
#
#             origin                     name
# ...
