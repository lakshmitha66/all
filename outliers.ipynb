# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_excel('D:/aiml/excel/mtcars.xlsx')
print(dataset.describe())
# Out:
#                 mpg        cyl        disp          hp       drat         wt  \
# count  3.200000e+01  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   6.944445e+08   6.187500  230.721875  146.687500   3.596563   3.217250
# std    3.928371e+09   1.785922  123.938694   68.562868   0.534679   0.978457
# min    1.040000e+01   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    1.542500e+01   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    1.920000e+01   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    2.320000e+01   8.000000  326.000000  180.000000   3.920000   3.610000
# max    2.222222e+10   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
plt.hist(dataset.tail()['mpg'],bins=15)
plt.show()

# %%
lowerLimit=dataset['mpg'].quantile(0.05)
lowerLimit
# Out:
# 11.995000000000001

# %%
dataset[dataset['mpg'] < lowerLimit]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
#
#     gear  carb
# 14     3     4
# 15     3     4

# %%
upperLimit=dataset['mpg'].quantile(0.05)
upperLimit
# Out:
# 11.995000000000001

# %%
dataset[dataset['mpg'] > upperLimit]
# Out:
#                 model           mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0           Mazda RX4  2.222222e+10    6  160.0  110  3.90  2.620  16.46   0
# 1       Mazda RX4 Wag  2.100000e+01    6  160.0  110  3.90  2.875  17.02   0
# 2          Datsun 710  2.280000e+01    4  108.0   93  3.85  2.320  18.61   1
# 3      Hornet 4 Drive  2.140000e+01    6  258.0  110  3.08  3.215  19.44   1
# 4   Hornet Sportabout  1.870000e+01    8  360.0  175  3.15  3.440  17.02   0
# 5             Valiant  1.810000e+01    6  225.0  105  2.76  3.460  20.22   1
# 6          Duster 360  1.430000e+01    8  360.0  245  3.21  3.570  15.84   0
# 7           Merc 240D  2.440000e+01    4  146.7   62  3.69  3.190  20.00   1
# 8            Merc 230  2.280000e+01    4  140.8   95  3.92  3.150  22.90   1
# 9            Merc 280  1.920000e+01    6  167.6  123  3.92  3.440  18.30   1
# 10          Merc 280C  1.780000e+01    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
dataset=dataset[(dataset['mpg'] > lowerLimit) & (dataset['mpg'] < upperLimit)]

# %%
dataset
# Out:
# Empty DataFrame
# Columns: [model, mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb]
# Index: []
